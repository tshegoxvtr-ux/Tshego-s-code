# %%
data = {"details":[["Data Scientist","17"],["Software Engineering","18"],["Paleantologist","19"],["Doctor","17"],["Lecture","16"],["Civil Engineering","19"],["Receptionist","18"],["Chef","17"]],
         "Marks":[78,89,45,78,56,85,55,65],
          "Pass_mark":[50,74],
            "Pass":[True,True,False,True,False,True,False,True],
            "Learner_id":[180,181,183,184,185,186,187,188],
            "name":["Tshepo","Thabang","Trevor","Thabo","Angel","Precious","Ayanda","Thando"]
       }

# %%
learner = {
    "Age": [17,18,19,17,16,19,18,17],
    "learner_name": [ "Tshepo","Thabang","Trevor","Thabo","Angel","Precious","Ayanda","Thanda"],
    "ID": [180,181,182,183,184,185,186,187,188]
}

total = 0
#AverageAge
for i in learner["Age"]:
    total += i
num = len(learner["Age"])
average = total/num
print(f"Average learner age: {average}")

for i in range(len(learner["learner_name"])):
    print(f"{learner['learner_name'][i]} - {learner['Age'][i]} - {learner['ID'][i]}")
# Out:
# Average learner age: 17.625
# Tshepo - 17 - 180
# Thabang - 18 - 181
# Trevor - 19 - 182
# Thabo - 17 - 183
# Angel - 16 - 184
# Precious - 19 - 185
# Ayanda - 18 - 186
# Thanda - 17 - 187

# %%
## Number of Learners Passed/Failed
P = 0
F = 0
for i in data["Pass"]:
    if i == True:
        P += 1
    else:
        F += 1
for j in range(len(data["Pass"])):
    print(f"{data["Learner_name"][j]} - {data["Pass"][j]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 10
#       6         P += 1
#       7     else:
#       8         F += 1
#       9 for j in range(len(data["Pass"])):
# ---> 10     print(f"{data["Learner_name"][j]} - {data["Pass"][j]}")
#
# KeyError: 'Learner_name'

# %%
question = int(input("Would you like to add  new learner(1) or View learner details(2) View learner results(3) or Update learner details(4) or Remove learners from the system(5)?"))

if question == 1:
    name = input("Please Enter Name:")
    data["Learner_name"].append(name)
    age = int(input("Please Enter learner_ID:"))
    data["ID"].append(id)
    search = input("Would you like to view learner results?")
    if search == "Yes":
        data["learner_name"].append(learner_name)
         print(f"Learners results!")
    view = input("Would you like to view learner details(Yes) or Would you like to update learner details(No)?")
    if view == "Yes"
        data["learner_name"].append(learner_name)
        print(f"Learner details!")
    else:
        if view == "No"
        data["learner_name"].append(learner_name)
        print(f"Update learner details!")
    else:
        remove = input("Would you like to remove leraner?")
        if remove == "Yes"
        data["learner_name"].append(learner_name)
        print(f"Learner removed!")

else:
    print(f"Number of learner: {num}")
    print(f"Average of Learner Age: {average}")
    print(f"Learner details: {details}")
    print(f"Learner results: {results}")

# %%
#Certification qualification
if average >= 50:
    certificate = Yes
else:
    certificate = No

if mark < 0 or mark > 100:
    print(f"Invalid marks")


#Determine result
if average < 50:
    status = "Fail"
elif average < 75:
    status = "Pass"
else:
    status = "Pass with Distinction"


#Do they deserce a Certificate?
if average >= 50:
    print("Qualifies for certificate")
else:
    print("Does not qualify")
